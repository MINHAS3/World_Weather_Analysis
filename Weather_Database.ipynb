# %%
# %run API_practice.ipynb
# %run WeatherPy.ipynb
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
# print (weather_api_key)
# %run config.ipynb

# %%
import random
random.randint(-90, 90)
# Out:
# 71

# %%
x = 1
latitudes = []
longitudes = []
while x < 1501:
    random_lat = random.randint(-90, 89) + random.random()
    random_long = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    longitudes.append(random_long)
    x += 1

# %%
len(latitudes)
# Out:
# 1500

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for index in range(len(latitudes)):
    city = citipy.nearest_city(latitudes[index], longitudes[index]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
(cities)
# Out:
# ['walvis bay',
#  'naryan-mar',
#  'yar-sale',
#  'lichinga',
#  'ilulissat',
#  'hofn',
#  'bambous virieux',
#  'cap malheureux',
#  'salalah',
#  'belushya guba',
#  'tiznit',
#  'krasnoselkup',
#  'robertsport',
#  'arraial do cabo',
#  'sao filipe',
#  'mar del plata',
#  'carutapera',
#  'tasiilaq',
#  'charlottesville',
#  'adrian',
#  'louisbourg',
#  'humaita',
#  'beloha',
#  'east london',
#  'hermanus',
#  'cape town',
#  'bredasdorp',
#  'nouadhibou',
#  'port alfred',
#  'dzilam gonzalez',
#  'mahebourg',
#  'pangnirtung',
#  'vila franca do campo',
#  'thouars',
#  'sedelnikovo',
#  'busselton',
#  'sorvag',
#  'anloga',
#  'punta arenas',
#  'guajara-mirim',
#  'wagar',
#  'tatsinskaya',
#  'muborak',
#  'chuy',
#  'natal',
#  'ushuaia',
#  'sal rei',
#  'prado',
#  'clarence town',
#  'carnarvon',
#  'victoria',
#  'general roca',
#  'cazaje',
#  'illoqqortoormiut',
#  'nyandoma',
#  'acarau',
#  'kajaani',
#  'pisco',
#  'sabha',
#  'ostrovnoy',
#  'vagur',
# ...

# %%
import citipy
from datetime import datetime
from citipy import citipy
city = citipy.nearest_city(latitudes[0], longitudes[0]).city_name
print (city)
# Out:
# walvis bay

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print (url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d8c8771119d21d30d09f857668d8b13a

# %%
# Create an endpoint URL for a city.

city_url = url + "&q=" + "Aksarka"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
city_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d8c8771119d21d30d09f857668d8b13a&q=Aksarka'

# %%
city_weather.json()
# Out:
# {'coord': {'lon': 67.8, 'lat': 66.56},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10d'}],
#  'base': 'stations',
#  'main': {'temp': 58.17,
#   'feels_like': 58.82,
#   'temp_min': 58.17,
#   'temp_max': 58.17,
#   'pressure': 1003,
#   'humidity': 92,
#   'sea_level': 1003,
#   'grnd_level': 999},
#  'wind': {'speed': 2.1, 'deg': 312},
#  'rain': {'1h': 0.51},
#  'clouds': {'all': 100},
#  'dt': 1594490282,
#  'sys': {'country': 'RU', 'sunrise': 1594412765, 'sunset': 1594492928},
#  'timezone': 18000,
#  'id': 1512019,
#  'name': 'Aksarka',
#  'cod': 200}

# %%
city_weather.text
# Out:
# '{"coord":{"lon":67.8,"lat":66.56},"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}],"base":"stations","main":{"temp":58.17,"feels_like":58.82,"temp_min":58.17,"temp_max":58.17,"pressure":1003,"humidity":92,"sea_level":1003,"grnd_level":999},"wind":{"speed":2.1,"deg":312},"rain":{"1h":0.51},"clouds":{"all":100},"dt":1594490282,"sys":{"country":"RU","sunrise":1594412765,"sunset":1594492928},"timezone":18000,"id":1512019,"name":"Aksarka","cod":200}'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d8c8771119d21d30d09f857668d8b13a'

# %%
# # Loop through all the cities in the list.
all_city_data_df = pd.DataFrame()
for city in cities:
    city_url = url + "&q=" + city.replace(" ","+")
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        try: 
            city_rain = city_weather["rain"]["1h"] 
        except: 
            city_rain = 0

        try: 
            city_snow = city_weather["snow"]["1h"] 
        except: 
            city_snow = 0
        city_name = city_weather["name"]
    #     city_snow = city_weather["snow"]["1h"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city_name,
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Rain": city_rain,
                          "snow": city_snow})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    # Indicate that Data Loading is complete.
    print("-----------------------------")
    print("Data Retrieval Complete      ")
    print("-----------------------------")
    city_data_df = pd.DataFrame(city_data)
    all_city_data_df = all_city_data_df.append(city_data_df)
    city_data.clear()

#     # Group cities in sets of 50 for logging purposes.
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 1
#     # Create endpoint URL with each city.
#     city_url = url + "&q=" + city.replace(" ","+")

#     # Log the URL, record, and set numbers and the city.
#     print(f"Processing Record {record_count} of Set {set_count} | {city}")
#     # Add 1 to the record count.
#     record_count += 1
# Out:
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# -----------------------------
# Data Retrieval Complete
# ...

# %%
all_city_data_df
# Out:
#            City Country                 Date    Lat    Lng  Max Temp  \
# 0    Walvis Bay      NA  2020-07-11 18:55:42 -22.96  14.51     57.00
# 0    Naryan-Mar      RU  2020-07-11 18:55:42  67.67  53.09     53.94
# 0      Yar-Sale      RU  2020-07-11 18:55:42  66.83  70.83     52.07
# 0      Lichinga      MZ  2020-07-11 18:55:42 -13.31  35.24     58.95
# 0     Ilulissat      GL  2020-07-11 18:55:42  69.22 -51.10     46.40
# ..          ...     ...                  ...    ...    ...       ...
# 0     Havøysund      NO  2020-07-11 18:57:06  71.00  24.66     55.40
# 0   Caraballeda      VE  2020-07-11 18:57:06  10.61 -66.85     82.00
# 0     Ituiutaba      BR  2020-07-11 18:57:06 -18.97 -49.47     84.06
# 0      Balkhash      KZ  2020-07-11 18:57:06  46.84  74.98     70.81
# 0    Den Helder      NL  2020-07-11 18:56:42  52.96   4.76     61.00
#
#     Humidity  Cloudiness  Wind Speed  Rain  snow
# 0         76           0        8.05   0.0     0
# ...

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
all_city_data_df.to_csv(output_data_file, index_label="City_ID")
