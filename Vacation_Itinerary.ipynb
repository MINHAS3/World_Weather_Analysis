# %%
import pandas as pd
df = pd.read_csv("weather_data/WeatherPy_vacation.csv")

# %%
df.groupby(["Country"]).count()
# Out:
#          Unnamed: 0  City  Max Temp  Lat  Lng  Hotel Name
# Country
# AF                1     1         1    1    1           0
# AL                2     2         2    2    2           2
# AO                4     4         4    4    4           4
# AR                1     1         1    1    1           1
# BR                7     7         7    7    7           7
# CA                6     6         6    6    6           6
# CD                5     5         5    5    5           2
# CF                7     7         7    7    7           0
# CG                1     1         1    1    1           1
# CI                5     5         5    5    5           5
# CL                2     2         2    2    2           2
# CM                1     1         1    1    1           1
# CN                2     2         2    2    2           2
# CV                1     1         1    1    1           1
# EC                1     1         1    1    1           1
# ...

# %%
Country_CA = df.loc[df["Country"] =="CA"][:4]
Country_CA
# Out:
#     Unnamed: 0              City Country  Max Temp    Lat    Lng  \
# 4           15    Sturgeon Falls      CA     68.00  46.36 -79.93
# 17          94  Sault Ste. Marie      CA     66.20  46.52 -84.33
# 64         311           Halifax      CA     73.99  44.65 -63.57
# 87         392     Kirkland Lake      CA     66.20  48.14 -80.04
#
#        Hotel Name
# 4   Lincoln Motel
# 17    Comfort Inn
# 64  Hotel Halifax
# 87    Comfort Inn

# %%
Country_CA.iloc[0:4]["Lng"]
# Out:
# 4    -79.93
# 17   -84.33
# 64   -63.57
# 87   -80.04
# Name: Lng, dtype: float64

# %%
import gmaps
import gmaps.datasets
from config import g_key
gmaps.configure(api_key=g_key)

# Latitude-longitude pairs
North_Bay = (46.32, -79.47)
Torbay = (47.67, -52.73)
Sept_Iles = (50.20, -66.38)
Havre_St_Pierre = (50.23, -63.60)

fig = gmaps.figure()
North_Bay2Havre_St_Pierre = gmaps.directions_layer(North_Bay, Havre_St_Pierre)
fig.add_layer(North_Bay2Havre_St_Pierre)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
fig = gmaps.figure()
North_Bay2Havre_St_Pierre = gmaps.directions_layer(
        North_Bay, Havre_St_Pierre,
        travel_mode='DRIVING')
fig.add_layer(North_Bay2Havre_St_Pierre)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
fig = gmaps.figure()
North_Bay2Havre_St_Pierre = gmaps.directions_layer(
        North_Bay, Havre_St_Pierre,
        travel_mode='BICYCLING')
fig.add_layer(North_Bay2Havre_St_Pierre)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
fig = gmaps.figure()
North_Bay2Havre_St_Pierre = gmaps.directions_layer(
        North_Bay, Havre_St_Pierre,
        travel_mode='WALKING')
fig.add_layer(North_Bay2Havre_St_Pierre)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = Country_CA_df[["Lat", "Lng"]]
max_temp = Country_CA_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-9aa4d5782262> in <module>
#       1 # Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
# ----> 2 locations = Country_CA_df[["Lat", "Lng"]]
#       3 max_temp = Country_CA_df["Max Temp"]
#       4 fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#       5 heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
#
# NameError: name 'Country_CA_df' is not defined
